# %%
from urllib.request import Request, urlopen
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# in some cases a pattern like the following can be used to read data into dbfs for read

# import urllib.request
# urllib.request.urlretrieve("https://address.com/data.csv.gz","/tmp/data.csv.gz")
# dbutils.fs.mv("file:/tmp/data.csv.gz","dbfs:/data/data.csv.gz")
# df = spark.read.format('csv').load("dbfs:/data/data.csv.gz")

# but if it gives a 403  error we can drop back to importing via pandas
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# formulate a request
req = Request("https://simplemaps.com/static/data/country-cities/gb/gb.csv")
req.add_header(
  'User-Agent', 
  'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0'
)
content = urlopen(req)
 
# use the request to populate a dataframe and convert to a spark dataframe
pandas_df = pd.read_csv(content)
df = spark.createDataFrame(pandas_df)
 
# some towns in the data do not have a population stated
# lets assume they are smaller towns and fill population in as 5000
df = df.fillna(5000)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>lat</th><th>lng</th><th>country</th><th>iso2</th><th>admin</th><th>capital</th><th>population</th><th>population_proper</th></tr></thead><tbody><tr><td>London</td><td>51.514247999999995</td><td>-0.093145</td><td>United Kingdom</td><td>GB</td><td>null</td><td>primary</td><td>8567000.0</td><td>7421209.0</td></tr><tr><td>Birmingham</td><td>52.466667</td><td>-1.916667</td><td>United Kingdom</td><td>GB</td><td>Birmingham</td><td>admin</td><td>2285000.0</td><td>984333.0</td></tr><tr><td>Manchester</td><td>53.5</td><td>-2.2166669999999997</td><td>United Kingdom</td><td>GB</td><td>Manchester</td><td>admin</td><td>2230000.0</td><td>395515.0</td></tr><tr><td>Leeds</td><td>53.8</td><td>-1.583333</td><td>United Kingdom</td><td>GB</td><td>Leeds</td><td>admin</td><td>1529000.0</td><td>455123.0</td></tr><tr><td>Sheffield</td><td>53.36666700000001</td><td>-1.5</td><td>United Kingdom</td><td>GB</td><td>Sheffield</td><td>admin</td><td>1292900.0</td><td>552700.0</td></tr><tr><td>Glasgow</td><td>55.833332999999996</td><td>-4.25</td><td>United Kingdom</td><td>GB</td><td>Glasgow City</td><td>admin</td><td>1160000.0</td><td>610268.0</td></tr><tr><td>Newcastle upon Tyne</td><td>54.98805600000001</td><td>-1.619444</td><td>United Kingdom</td><td>GB</td><td>Newcastle upon Tyne</td><td>admin</td><td>882000.0</td><td>192382.0</td></tr><tr><td>Nottingham</td><td>52.966667</td><td>-1.166667</td><td>United Kingdom</td><td>GB</td><td>Nottingham</td><td>admin</td><td>825600.0</td><td>305700.0</td></tr><tr><td>Liverpool</td><td>53.416667000000004</td><td>-3.0</td><td>United Kingdom</td><td>GB</td><td>Liverpool</td><td>admin</td><td>811000.0</td><td>468945.0</td></tr><tr><td>Southend-on-Sea</td><td>51.533333</td><td>0.7</td><td>United Kingdom</td><td>GB</td><td>Southend-on-Sea</td><td>admin</td><td>618386.0</td><td>173600.0</td></tr><tr><td>Bristol</td><td>51.45</td><td>-2.583333</td><td>United Kingdom</td><td>GB</td><td>Bristol, City of</td><td>admin</td><td>553528.0</td><td>430713.0</td></tr><tr><td>Edinburgh</td><td>55.95</td><td>-3.2</td><td>United Kingdom</td><td>GB</td><td>Edinburgh, City of</td><td>admin</td><td>504966.0</td><td>435791.0</td></tr><tr><td>Brighton</td><td>50.833333</td><td>-0.15</td><td>United Kingdom</td><td>GB</td><td>Brighton and Hove</td><td>null</td><td>503008.0</td><td>139001.0</td></tr><tr><td>Bradford</td><td>53.783333</td><td>-1.75</td><td>United Kingdom</td><td>GB</td><td>Bradford</td><td>admin</td><td>501700.0</td><td>293717.0</td></tr><tr><td>Leicester</td><td>52.63333299999999</td><td>-1.133333</td><td>United Kingdom</td><td>GB</td><td>Leicester</td><td>admin</td><td>457983.0</td><td>339239.0</td></tr><tr><td>Sunderland</td><td>54.91194399999999</td><td>-1.383333</td><td>United Kingdom</td><td>GB</td><td>Sunderland</td><td>admin</td><td>452934.0</td><td>177965.0</td></tr><tr><td>Belfast</td><td>54.6</td><td>-5.933333</td><td>United Kingdom</td><td>GB</td><td>Belfast</td><td>null</td><td>450406.0</td><td>274770.0</td></tr><tr><td>Portsmouth</td><td>50.766667</td><td>-1.083333</td><td>United Kingdom</td><td>GB</td><td>Portsmouth</td><td>admin</td><td>442252.0</td><td>205100.0</td></tr><tr><td>Bournemouth</td><td>50.716667</td><td>-1.8833330000000001</td><td>United Kingdom</td><td>GB</td><td>Bournemouth</td><td>admin</td><td>426945.0</td><td>163600.0</td></tr><tr><td>Middlesbrough</td><td>54.572778</td><td>-1.162778</td><td>United Kingdom</td><td>GB</td><td>Redcar and Cleveland</td><td>admin</td><td>416042.0</td><td>142707.0</td></tr><tr><td>Coventry</td><td>52.416667</td><td>-1.55</td><td>United Kingdom</td><td>GB</td><td>Coventry</td><td>admin</td><td>388271.0</td><td>308313.0</td></tr><tr><td>Southampton</td><td>50.9</td><td>-1.4</td><td>United Kingdom</td><td>GB</td><td>Southampton</td><td>admin</td><td>384417.0</td><td>384417.0</td></tr><tr><td>Reading</td><td>51.433333000000005</td><td>-1.0</td ...

# %%
from pyspark.sql.functions import col
 
data = ",\n".join(
  map(
    lambda row: "[{}, {}, {}]".format(
      row[0], row[1], row[2]
    ), df.select(
      col("lat"),col("lng"),col("population")/1000
    ).collect()
  )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
displayHTML("""
<html>
<head>
 <link rel="stylesheet" href="https://unpkg.com/leaflet@1.3.1/dist/leaflet.css"
   integrity="sha512-Rksm5RenBEKSKFjgI3a41vrjkw4EVPlJ3+OiI65vTjIdo9brlAacEuKOiQ5OFh7cOI1bkDwLqdLw3Zg0cRJAAQ=="
   crossorigin=""/>
 <script src="https://unpkg.com/leaflet@1.3.1/dist/leaflet.js"
   integrity="sha512-/Nsx9X4HebavoBvEBuyp3I7od5tA0UzAxs+j83KgC8PU0kgB4XiK4Lfe4y4cgBtaRJQEIFCW+oC506aPT2L1zw=="
   crossorigin=""></script>
 <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.heat/0.2.0/leaflet-heat.js"></script>
</head>
<body>
  <div id="uk_map_id" style="width:768px; height:1024px"></div>
  <script>
    var uk_map = L.map('uk_map_id').setView([55,-5], 6);
    var tiles = L.tileLayer('http://{s}.tile.osm.org/{z}/{x}/{y}.png', {
      attribution: '&copy; <a href="http://osm.org/copyright">OpenStreetMap</a> contributors',
    }).addTo(uk_map);
    var heat = L.heatLayer([""" + data + """], {radius: 30}).addTo(uk_map);
  </script>
</body>
</html>
""")
# Out:
# <html>
# <head>
#  <link rel="stylesheet" href="https://unpkg.com/leaflet@1.3.1/dist/leaflet.css"
#    integrity="sha512-Rksm5RenBEKSKFjgI3a41vrjkw4EVPlJ3+OiI65vTjIdo9brlAacEuKOiQ5OFh7cOI1bkDwLqdLw3Zg0cRJAAQ=="
#    crossorigin=""/>
#  <script src="https://unpkg.com/leaflet@1.3.1/dist/leaflet.js"
#    integrity="sha512-/Nsx9X4HebavoBvEBuyp3I7od5tA0UzAxs+j83KgC8PU0kgB4XiK4Lfe4y4cgBtaRJQEIFCW+oC506aPT2L1zw=="
#    crossorigin=""></script>
#  <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.heat/0.2.0/leaflet-heat.js"></script>
# </head>
# <body>
#   <div id="uk_map_id" style="width:768px; height:1024px"></div>
#   <script>
#     var uk_map = L.map('uk_map_id').setView([55,-5], 6);
#     var tiles = L.tileLayer('http://{s}.tile.osm.org/{z}/{x}/{y}.png', {
#       attribution: '&copy; <a href="http://osm.org/copyright">OpenStreetMap</a> contributors',
#     }).addTo(uk_map);
#     var heat = L.heatLayer([[51.514247999999995, -0.093145, 8567.0],
# [52.466667, -1.916667, 2285.0],
# [53.5, -2.2166669999999997, 2230.0],
# [53.8, -1.583333, 1529.0],
# [53.36666700000001, -1.5, 1292.9],
# [55.833332999999996, -4.25, 1160.0],
# [54.98805600000001, -1.619444, 882.0],
# [52.966667, -1.166667, 825.6],
# [53.416667000000004, -3.0, 811.0],
# [51.533333, 0.7, 618.386],
# [51.45, -2.583333, 553.528],
# [55.95, -3.2, 504.966],
# [50.833333, -0.15, 503.008],
# [53.783333, -1.75, 501.7],
# [52.63333299999999, -1.133333, 457.983],
# [54.91194399999999, -1.383333, 452.934],
# [54.6, -5.933333, 450.406],
# [50.766667, -1.083333, 442.252],
# [50.716667, -1.8833330000000001, 426.945],
# [54.572778, -1.162778, 416.042],
# [52.416667, -1.55, 388.271],
# [50.9, -1.4, 384.417],
# [51.433333000000005, -1.0, 369.804],
# [53.783333, -0.31666700000000003, 302.296],
# [53.816667, -3.05, 272.792],
# [50.396389, -4.138611, 247.297],
# [51.883333, -0.416667, 235.958],
# [51.75, -1.25, 192.796],
# [52.63333299999999, 1.3, 190.756],
# [57.166667000000004, -2.1, 189.364],
# [53.966667, -1.083333, 158.947],
# [56.5, -2.9666669999999997, 151.592],
# [52.083333, 1.166667, 143.767],
# [52.583332999999996, -0.25, 140.141],
# [52.2, 0.116667, 128.488],
# [50.683333000000005, -3.483333, 113.118],
# [51.379444, -2.365556, 93.238],
# [53.2, -2.916667, 89.531],
# [55.933333, -4.75, 74.635],
# [54.88333299999999, -2.933333, 72.633],
# [54.287222, -0.414167, 70.571],
# [55.45, -4.616667, 69.042],
# [57.466667, -4.233333, 45.158],
# [56.4, -3.433333, 39.654],
# [51.133333, 1.266667, 36.384],
# [55.066667, -3.55, 31.044],
# [54.601240000000004, -7.29085, 21.056],
# [50.113611, -5.547778, 20.812],
# [56.816667, -5.116667, 9.652],
# [58.966667, -2.95, 8.5],
# [58.433333, -3.083333, 7.147],
# [60.15, -1.15, 6.594],
# [51.559666, 0.07080499999999999, 5.0],
# [51.733333, 0.483333, 5.0],
# [51.345833, -2.967778, 5.0],
# [53.266667000000005, -4.3333330000000005, 5.0],
# [53.666667000000004, -3.0, 5.0],
# [54.348119999999994, -6.64957, 5.0],
# [51.383333, 0.516667, 5.0],
# [53.61666700000001, -2.15, 5.0],
# [55.783333, -4.0, 5.0],
# [51.626667, -3.476111, 5.0],
